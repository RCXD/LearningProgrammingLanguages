# %%
# Lab 9 XOR
import tensorflow as tf
import numpy as np

tf.set_random_seed(777)  # for reproducibility

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])

W = tf.Variable(tf.random_normal([2, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# Hypothesis using sigmoid: tf.div(1., 1. + tf.exp(tf.matmul(X, W)))
hypothesis = tf.sigmoid(tf.matmul(X, W) + b) 
#출력이 단순히 0, 1뿐이므로 Logistic Regression을 사용한다.

# cost/loss function
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# Accuracy computation
# True if hypothesis>0.5 else False
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# Launch graph
with tf.Session() as sess:
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for step in range(10001): #상당히 긴 시간동안 실행함
        _, cost_val, w_val = sess.run(
                  [train, cost, W], feed_dict={X: x_data, Y: y_data}
        )
        if step % 100 == 0:
            print(step, cost_val, w_val)

    # Accuracy report
    #여기서는 훈련데이터를 그대로 정확도 평가에 사용하였음
    h, c, a = sess.run(
              [hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data}
    )
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 0.8875433 [[0.7863567]
#  [0.6628261]]
# 100 0.6957383 [[0.23303682]
#  [0.16537341]]
# 200 0.69428164 [[0.1468633 ]
#  [0.11071217]]
# 300 0.69366115 [[0.09652311]
#  [0.07720933]]
# 400 0.6933805 [[0.06380111]
#  [0.05348315]]
# 500 0.69325316 [[0.0423411 ]
#  [0.03682906]]
# 600 0.69319546 [[0.02819196]
#  [0.02524734]]
# 700 0.6931691 [[0.0188217 ]
#  [0.01724866]]
# 800 0.6931572 [[0.01259337]
#  [0.01175304]]
# 900 0.6931518 [[0.00844097]
#  [0.00799206]]
# 1000 0.69314927 [[0.00566576]
#  [0.00542594]]
# 1100 0.69314814 [[0.00380732]
#  [0.00367921]]
# 1200 0.69314766 [[0.0025608 ]
#  [0.00249235]]
# 1300 0.69314736 [[0.00172364]
#  [0.00168707]]
# 1400 0.6931473 [[0.00116083]
#  [0.00114128]]
# 1500 0.6931473 [[0.00078214]
#  [0.0007717 ]]
# 1600 0.6931472 [[0.00052721]
#  [0.00052162]]
# 1700 0.6931472 [[0.00035546]
#  [0.00035248]]
# 1800 0.6931472 [[0.00023971]
#  [0.00023812]]
# 1900 0.6931472 [[0.00016166]
#  [0.00016081]]
# 2000 0.6931472 [[0.00010905]
# ...

# %% [markdown]
# Logist Regression으로는 정확도가 0.5밖에 나오지 않는다.(실패)
# ---
# Neural Network으로 구현하기

# %%
# Lab 9 XOR
import tensorflow as tf
import numpy as np

tf.set_random_seed(777)  # for reproducibility

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])

W1 = tf.Variable(tf.random_normal([2, 2]), name='weight1')
b1 = tf.Variable(tf.random_normal([2]), name='bias1')
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)
#lecture에서 정리했던 것처럼, layer 1을 구현함. 
#입력벡터에 대해 각각 구현하기보다 matrix를 이용하여 간단히 구현

W2 = tf.Variable(tf.random_normal([2, 1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2')
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) + b2)
#두 번째 레이어 구현: 첫 번째 레이어를 인자로 전달

# cost/loss function
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# Accuracy computation
# True if hypothesis>0.5 else False
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# Launch graph
#학습 과정은 다를게 없음
with tf.Session() as sess:
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for step in range(10001):
        _, cost_val = sess.run([train, cost], feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, cost_val)

    # Accuracy report
    h, p, a = sess.run(
        [hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data}
    )
    
    print(f"\nHypothesis:\n{h} \nPredicted:\n{p} \nAccuracy:\n{a}")
# Out:
# 0 1.3039297
# 100 0.6936542
# 200 0.69290876
# 300 0.69280314
# 400 0.69267625
# 500 0.69252
# 600 0.6923247
# 700 0.6920767
# 800 0.69175696
# 900 0.69133985
# 1000 0.69078827
# 1100 0.6900508
# 1200 0.68905705
# 1300 0.6877116
# 1400 0.68589175
# 1500 0.6834475
# 1600 0.68020713
# 1700 0.6759876
# 1800 0.6706023
# 1900 0.66386443
# 2000 0.6555872
# 2100 0.6455984
# 2200 0.6337761
# 2300 0.6200976
# 2400 0.6046678
# 2500 0.58768165
# 2600 0.56931925
# 2700 0.54960686
# 2800 0.5283126
# 2900 0.50494325
# 3000 0.47891203
# 3100 0.44988438
# 3200 0.4181077
# 3300 0.38445038
# 3400 0.35014123
# 3500 0.31644633
# 3600 0.2844466
# 3700 0.25491926
# 3800 0.22830033
# 3900 0.20471701
# 4000 0.18406776
# 4100 0.1661124
# 4200 0.15054828
# 4300 0.1370608
# 4400 0.1253531
# 4500 0.11515963
# 4600 0.10625054
# 4700 0.0984303
# 4800 0.091534615
# 4900 0.085426226
# 5000 0.07999065
# 5100 0.075132266
# 5200 0.07077117
# 5300 0.0668406
# 5400 0.06328413
# 5500 0.060054332
# 5600 0.057110883
# ...

# %% [markdown]
# 차이점은 레이어가 1개냐 2개냐의 차이 뿐이었다.

# %% [markdown]
# ---
# Wide NN for XOR
# 레이어 1과 2는 단 두 개의 인자로 연결되었는데, 이것을 실험적으로 과장하기로 함.
# *?* 일반적으로 내부 연결의 수는 입력 개수보다 적게 한다??
# 레이어 1과 2 사이의 입력을 여러개로 취함

# %%
# Lab 9 XOR
import tensorflow as tf
import numpy as np

tf.set_random_seed(777)  # for reproducibility

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])

W1 = tf.Variable(tf.random_normal([2, 10]), name='weight1')
b1 = tf.Variable(tf.random_normal([10]), name='bias1')
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)

W2 = tf.Variable(tf.random_normal([10, 1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2')
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) + b2)

# cost/loss function
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# Accuracy computation
# True if hypothesis>0.5 else False
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# Launch graph
with tf.Session() as sess:
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for step in range(10001):
        _, cost_val = sess.run([train, cost], feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, cost_val)

    # Accuracy report
    h, p, a = sess.run(
        [hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data}
    )
    
    print(f"\nHypothesis:\n{h} \nPredicted:\n{p} \nAccuracy:\n{a}")
# Out:
# 0 1.9905149
# 100 0.6553618
# 200 0.63514215
# 300 0.6126211
# 400 0.58801234
# 500 0.5613751
# 600 0.5326827
# 700 0.50192726
# 800 0.46918637
# 900 0.43468404
# 1000 0.3988518
# 1100 0.36236298
# 1200 0.32609847
# 1300 0.2910328
# 1400 0.25806937
# 1500 0.22789127
# 1600 0.20088454
# 1700 0.17714623
# 1800 0.15654977
# 1900 0.13882807
# 2000 0.12364827
# 2100 0.110663764
# 2200 0.09954712
# 2300 0.09000524
# 2400 0.081785195
# 2500 0.07467286
# 2600 0.06848988
# 2700 0.06308827
# 2800 0.058345757
# 2900 0.054161802
# 3000 0.050452866
# 3100 0.047150083
# 3200 0.044196136
# 3300 0.041543156
# 3400 0.039151084
# 3500 0.036986228
# 3600 0.035019986
# 3700 0.033228233
# 3800 0.03159025
# 3900 0.030088458
# 4000 0.028707564
# 4100 0.02743452
# 4200 0.026257902
# 4300 0.025167767
# 4400 0.024155479
# 4500 0.023213504
# 4600 0.02233512
# 4700 0.021514496
# 4800 0.02074632
# 4900 0.020026073
# 5000 0.019349627
# 5100 0.018713258
# 5200 0.018113729
# 5300 0.017547993
# 5400 0.017013535
# ...

# %% [markdown]
# 가설함수의 출력값이 정답에 더욱 가까워진 것을 알 수 있다.
# 이것은 학습이 더 잘 되었다는 의미.
#
# ---
#
# Layer의 개수를 늘린 경우

# %%
# Lab 9 XOR
import tensorflow as tf
import numpy as np

tf.set_random_seed(777)  # for reproducibility

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

X = tf.placeholder(tf.float32, [None, 2])
Y = tf.placeholder(tf.float32, [None, 1])

#레이어 1의 출력 인자를 매우 크게 취하려면, 가중치 매트릭스를 조정한다.
W1 = tf.Variable(tf.random_normal([2, 10]), name='weight1')
b1 = tf.Variable(tf.random_normal([10]), name='bias1')
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)

W2 = tf.Variable(tf.random_normal([10, 10]), name='weight2')
b2 = tf.Variable(tf.random_normal([10]), name='bias2')
layer2 = tf.sigmoid(tf.matmul(layer1, W2) + b2)

W3 = tf.Variable(tf.random_normal([10, 10]), name='weight3')
b3 = tf.Variable(tf.random_normal([10]), name='bias3')
layer3 = tf.sigmoid(tf.matmul(layer2, W3) + b3)

W4 = tf.Variable(tf.random_normal([10, 1]), name='weight4')
b4 = tf.Variable(tf.random_normal([1]), name='bias4')
hypothesis = tf.sigmoid(tf.matmul(layer3, W4) + b4)

# cost/loss function
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# Accuracy computation
# True if hypothesis>0.5 else False
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# Launch graph
with tf.Session() as sess:
    # Initialize TensorFlow variables
    sess.run(tf.global_variables_initializer())

    for step in range(10001):
        _, cost_val = sess.run([train, cost], feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, cost_val)

    # Accuracy report
    h, c, a = sess.run(
        [hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data}
    )
    print("\nHypothesis: ", h, "\nCorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 0.9177859
# 100 0.65176237
# 200 0.6205077
# 300 0.5729829
# 400 0.50113535
# 500 0.39878595
# 600 0.27978438
# 700 0.17996421
# 800 0.116095334
# 900 0.079120025
# 1000 0.05734836
# 1100 0.043792058
# 1200 0.034839235
# 1300 0.02861399
# 1400 0.024095656
# 1500 0.020698467
# 1600 0.01806876
# 1700 0.015983172
# 1800 0.014295163
# 1900 0.012904989
# 2000 0.011743005
# 2100 0.01075918
# 2200 0.009916838
# 2300 0.009188416
# 2400 0.0085530225
# 2500 0.007994478
# 2600 0.00749999
# 2700 0.0070594684
# 2800 0.0066648275
# 2900 0.0063094273
# 3000 0.0059878747
# 3100 0.005695624
# 3200 0.005428978
# 3300 0.005184844
# 3400 0.004960541
# 3500 0.004753748
# 3600 0.004562673
# 3700 0.0043854658
# 3800 0.004220816
# 3900 0.004067477
# 4000 0.0039242595
# 4100 0.0037902934
# 4200 0.0036647213
# 4300 0.0035467925
# 4400 0.003435846
# 4500 0.0033312668
# 4600 0.003232544
# 4700 0.003139228
# 4800 0.0030508838
# 4900 0.0029671805
# 5000 0.0028876988
# 5100 0.0028121395
# 5200 0.0027402763
# ...

# %% [markdown]
# 레이어가 더 많을 수록 학습이 더 잘된다는 것을 볼 수 있다.

# %% [markdown]
# # Assigmnemt: MNIST 데이터를 뉴럴네트웍으로 학습시켜보기
